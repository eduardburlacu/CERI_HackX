# %% [markdown]
# # 2020 Covid dataset analysed

# %% [markdown]
# ## Part 1 - Feature Engineering

# %%
import pandas as pd
import os
import numpy as np
import tensorflow as tf
from datetime import datetime
from tensorflow import keras

# %%
list_of_df= []
for (root, dirs, files) in os.walk(os.path.join(os.getcwd(), "county_data")):
    for file in files:
        if file[-4:] == ".csv": 
            df = pd.read_csv(os.path.join(root, file))
            df = df.dropna()
            if len(df):
                name = df["areaName"][5]
                df = df.drop(df.columns[:3], axis=1)[::-1].reset_index(drop=True)
                df['y'] = df["newCasesBySpecimenDate"]/df["newVirusTestsBySpecimenDate"]
                df.columns=['Date','Cases','Deaths','Tests','y']
                df=df.set_index('Date')
                list_of_df.append([name,df])

# %%
list_of_df[0][1]
# Out:
#             Cases  Deaths  Tests         y
# Date
# 2020-03-20    1.0     1.0      4  0.250000
# 2020-03-21    0.0     1.0      5  0.000000
# 2020-03-22    0.0     0.0      9  0.000000
# 2020-03-23    0.0     0.0     11  0.000000
# 2020-03-24    0.0     0.0     11  0.000000
# ...           ...     ...    ...       ...
# 2022-11-10   11.0     0.0     66  0.166667
# 2022-11-11    0.0     0.0     45  0.000000
# 2022-11-12    5.0     0.0    176  0.028409
# 2022-11-13    3.0     0.0     32  0.093750
# 2022-11-14    5.0     0.0     67  0.074627
#
# [970 rows x 4 columns]

# %% [markdown]
# Now we have to set the target of the analysis. For a certain country, train a model that is trained on its 2020-01 -- 2020-05 dataset such that time is the input and the outputs are #of new cases. It will be tested on 2020-06 -- 2020-07 dataset.

# %%
list_of_features=['Cases','Deaths','Tests']
list_county=[x[0] for x in list_of_df]

def norm_feature(data,col=None):
    '''
    Given a DataFrame and a column, it normalises the data in a new column called NORM_column
    '''
    if col is None:
        a=(data-data.mean())/data.std()
    else: 
        a=(data[col]-data[col].mean())/data[col].std()
    name='NORM_'+ col
    data[name]=a
    return data

def normalize(data, train_split):
    data_mean = data[:train_split].mean(axis=0)
    data_std = data[:train_split].std(axis=0)
    return (data - data_mean) / data_std

features=[]
for name,df in list_of_df:
    for feature in list_of_features:
        a='NORM_'+feature
        if a not in features:
            features.append(a)
        if a not in df.columns:
            df = norm_feature(df, col=feature)

# %%
list_of_df[0][1].describe()
# Out:
#             Cases      Deaths        Tests           y    NORM_Cases  \
# count  970.000000  970.000000   970.000000  970.000000  9.700000e+02
# mean    37.091753    0.380412   806.815464    0.067686  1.602384e-18
# std     61.640514    0.844229   743.090305    0.114433  1.000000e+00
# min      0.000000    0.000000     4.000000    0.000000 -6.017431e-01
# 25%      6.000000    0.000000   167.250000    0.021164 -5.044045e-01
# 50%     20.000000    0.000000   560.500000    0.042134 -2.772811e-01
# 75%     45.000000    0.000000  1324.500000    0.076801  1.282963e-01
# max    839.000000   10.000000  3686.000000    2.000000  1.300943e+01
#
#         NORM_Deaths    NORM_Tests
# count  9.700000e+02  9.700000e+02
# mean  -2.283740e-15  2.815617e-17
# std    1.000000e+00  1.000000e+00
# min   -4.506034e-01 -1.080374e+00
# 25%   -4.506034e-01 -8.606834e-01
# 50%   -4.506034e-01 -3.314745e-01
# 75%   -4.506034e-01  6.966644e-01
# max    1.139453e+01  3.874609e+00

# %%
import matplotlib.pyplot as plt
def show_heatmap(data):
    plt.matshow(data.corr())
    plt.xticks(range(data.shape[1]), data.columns, fontsize=14, rotation=90)
    plt.gca().xaxis.tick_bottom()
    plt.yticks(range(data.shape[1]), data.columns, fontsize=14)

    cb = plt.colorbar()
    cb.ax.tick_params(labelsize=14)
    plt.title("Feature Correlation Heatmap", fontsize=14)
    plt.show()

show_heatmap(list_of_df[0][1])

# %%
ratio= 0.715
train_split = int( ratio * int(df.shape[0]))
def build_data(df,features,c): 
    '''
    Given a country c,the DataFrame, and a list of features, it returns a tuple of x_train, x_test, y_train, y_test
    '''
    
    a=df.loc[df.Country==c]
    a.set_index('Date')

    df_train=a.loc[:train_split]
    df_test=a.drop(df_train.index)

    X_train=pd.DataFrame(df_train.loc[:,features])
    X_test=pd.DataFrame(df_test.loc[:,features])
    y_train=pd.DataFrame(df_train['New cases'])
    y_test=pd.DataFrame(df_test['New cases'])
    return X_train, X_test, y_train, y_test, df_train, df_test


def build_data_world(df,features,cs):
    '''
    Given a list of countries c,the DataFrame, and a list of features, it returns a tuple of x_train, x_test, y_train, y_test
    '''
    X_train, X_test, y_train, y_test=None,None,None,None
    for c in cs:
        a=df.loc[df.Country==c]
        df_train=a.loc[a['NORM_delta_t']<2*ratio]
        df_test=a.drop(df_train.index)
        if X_train is None or X_test is None or y_train is None or y_test is None:
            X_train=tf.convert_to_tensor(df_train.loc[:,features])
            X_test=tf.convert_to_tensor(df_test.loc[:,features])
            y_train=tf.convert_to_tensor(df_train['New cases'])
            y_test=tf.convert_to_tensor(df_test['New cases'])
        else:
            X_train=tf.add(tf.convert_to_tensor(df_train.loc[:,features]),X_train)
            X_test=tf.add(tf.convert_to_tensor(df_test.loc[:,features]),X_test)
            y_train=tf.add(tf.convert_to_tensor(df_train['New cases']),y_train)
            y_test=tf.add(tf.convert_to_tensor(df_test['New cases']),y_test)
    return X_train, X_test, y_train, y_test, df_train, df_test
       
    
X_train, X_test, y_train, y_test, df_train, df_test= build_data(df=df,features=features,c='Italy')

# %%
assert(X_train.shape[0]==y_train.shape[0])
assert(X_test.shape[0]==y_test.shape[0])

# %% [markdown]
# Now everything is ready to train our model.

# %% [markdown]
# ## Part 2 - Deep Learning

# %%
step = 6
past = 80
future = 30
learning_rate = 0.001
batch_size = 10
epochs = 294

# %%
start = past + future
end = start + train_split
sequence_length = int(past / step)

# %%
X_train.shape
# Out:
# (134, 4)

# %%
def build_model():
    model=tf.keras.Sequential([
        tf.keras.layers.Dense(units=30,input_shape=[len(features)],activation='selu'),
        tf.keras.layers.Dense(units=20,activation='selu'),
        tf.keras.layers.Dense(units=15, activation='selu'),
        tf.keras.layers.Dense(units=1),
    ])
    model.compile(
    optimizer='adam',
    loss='mae',)
    return model

dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    X_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)

# %%
x_end = len(y_test) - past - future
label_start = train_split + past + future
#########################
dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    X_test,
    y_test,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)
for batch in dataset_train.take(1):
    inputs, targets = batch
print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# Input shape: (10, 13, 4)
# Target shape: (10, 1)

# %%
batch_size=20
epochs=204

#model1=build_model()
#history = model1.fit(
#    X_train, y_train,
#    validation_data=(X_test, y_test),
#    batch_size=batch_size,
#    epochs=epochs,)


inputs = keras.layers.Input(shape=(inputs.shape[1], inputs.shape[2]))
lstm_out = keras.layers.LSTM(32)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 13, 4)]           0
#
#  lstm_11 (LSTM)              (None, 32)                4736
#
#  dense_19 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 4,769
# Trainable params: 4,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
path_checkpoint = "model_checkpoint.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=5)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
    callbacks=[es_callback, modelckpt_callback],
)
# Out:
# Epoch 1/204
# 1/6 [====>.........................] - ETA: 7s - loss: 0.3405WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 2s 13ms/step - loss: 1664603.2500
# Epoch 2/204
# 4/6 [===================>..........] - ETA: 0s - loss: 12821.3076WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 25ms/step - loss: 1664304.2500
# Epoch 3/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3324WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 15ms/step - loss: 1663999.7500
# Epoch 4/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3435WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1663688.7500
# Epoch 5/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3686WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1663367.5000
# Epoch 6/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4098WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1663031.1250
# Epoch 7/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4701WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1662675.3750
# Epoch 8/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5541WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1662300.3750
# Epoch 9/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.6689WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1661911.0000
# Epoch 10/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.8240WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1661516.3750
# Epoch 11/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.0306WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1661121.5000
# Epoch 12/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3012WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1660726.7500
# Epoch 13/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6489WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1660326.8750
# Epoch 14/204
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0886WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1659917.8750
# Epoch 15/204
# 1/6 [====>.........................] - ETA: 0s - loss: 2.6372WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1659499.6250
# Epoch 16/204
# 1/6 [====>.........................] - ETA: 0s - loss: 3.3151WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1659080.1250
# Epoch 17/204
# 1/6 [====>.........................] - ETA: 0s - loss: 4.1429WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1658667.7500
# Epoch 18/204
# 1/6 [====>.........................] - ETA: 0s - loss: 5.1346WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1658267.7500
# Epoch 19/204
# 1/6 [====>.........................] - ETA: 0s - loss: 6.2923WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1657879.1250
# Epoch 20/204
# 1/6 [====>.........................] - ETA: 0s - loss: 7.6078WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1657499.5000
# Epoch 21/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.0664WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1657127.8750
# Epoch 22/204
# 1/6 [====>.........................] - ETA: 0s - loss: 10.6497WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1656766.3750
# Epoch 23/204
# 1/6 [====>.........................] - ETA: 0s - loss: 12.3330WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1656417.0000
# Epoch 24/204
# 1/6 [====>.........................] - ETA: 0s - loss: 14.0767WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1656076.8750
# Epoch 25/204
# 1/6 [====>.........................] - ETA: 0s - loss: 15.8306WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1655741.6250
# Epoch 26/204
# 1/6 [====>.........................] - ETA: 0s - loss: 17.5564WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1655410.7500
# Epoch 27/204
# 1/6 [====>.........................] - ETA: 0s - loss: 19.2367WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1655092.1250
# Epoch 28/204
# 1/6 [====>.........................] - ETA: 0s - loss: 20.8388WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1654795.3750
# Epoch 29/204
# 1/6 [====>.........................] - ETA: 0s - loss: 22.2590WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1654522.5000
# Epoch 30/204
# 1/6 [====>.........................] - ETA: 0s - loss: 23.3348WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1654269.8750
# Epoch 31/204
# 1/6 [====>.........................] - ETA: 0s - loss: 23.9281WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1654033.1250
# Epoch 32/204
# 1/6 [====>.........................] - ETA: 0s - loss: 23.9776WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1653809.0000
# Epoch 33/204
# 1/6 [====>.........................] - ETA: 0s - loss: 23.4978WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1653595.1250
# Epoch 34/204
# 1/6 [====>.........................] - ETA: 0s - loss: 22.5587WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1653389.0000
# Epoch 35/204
# 1/6 [====>.........................] - ETA: 0s - loss: 21.2641WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1653189.7500
# Epoch 36/204
# 1/6 [====>.........................] - ETA: 0s - loss: 19.7313WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1652996.1250
# Epoch 37/204
# 1/6 [====>.........................] - ETA: 0s - loss: 18.0732WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1652807.0000
# Epoch 38/204
# 1/6 [====>.........................] - ETA: 0s - loss: 16.3859WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1652622.0000
# Epoch 39/204
# 1/6 [====>.........................] - ETA: 0s - loss: 14.7415WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1652440.1250
# Epoch 40/204
# 1/6 [====>.........................] - ETA: 0s - loss: 13.1877WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1652261.5000
# Epoch 41/204
# 1/6 [====>.........................] - ETA: 0s - loss: 11.7515WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 15ms/step - loss: 1652085.5000
# Epoch 42/204
# 1/6 [====>.........................] - ETA: 0s - loss: 10.4437WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1651911.6250
# Epoch 43/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.2645WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1651739.8750
# Epoch 44/204
# 1/6 [====>.........................] - ETA: 0s - loss: 8.2078WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1651570.3750
# Epoch 45/204
# 1/6 [====>.........................] - ETA: 0s - loss: 7.2640WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1651402.3750
# Epoch 46/204
# 1/6 [====>.........................] - ETA: 0s - loss: 6.4224WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1651236.2500
# Epoch 47/204
# 1/6 [====>.........................] - ETA: 0s - loss: 5.6723WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1651071.2500
# Epoch 48/204
# 1/6 [====>.........................] - ETA: 0s - loss: 5.0035WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1650907.6250
# Epoch 49/204
# 1/6 [====>.........................] - ETA: 0s - loss: 4.4070WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1650745.3750
# Epoch 50/204
# 1/6 [====>.........................] - ETA: 0s - loss: 3.8745WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1650584.2500
# Epoch 51/204
# 1/6 [====>.........................] - ETA: 0s - loss: 3.3991WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1650424.2500
# Epoch 52/204
# 1/6 [====>.........................] - ETA: 0s - loss: 2.9747WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1650265.2500
# Epoch 53/204
# 1/6 [====>.........................] - ETA: 0s - loss: 2.5959WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 15ms/step - loss: 1650107.2500
# Epoch 54/204
# 1/6 [====>.........................] - ETA: 0s - loss: 2.2583WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1649950.0000
# Epoch 55/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.9578WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1649793.8750
# Epoch 56/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6913WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1649638.5000
# Epoch 57/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4555WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1649483.5000
# Epoch 58/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2481WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 15ms/step - loss: 1649329.3750
# Epoch 59/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.0665WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1649176.1250
# Epoch 60/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.9088WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1649023.0000
# Epoch 61/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.7730WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1648871.0000
# Epoch 62/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.6574WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 15ms/step - loss: 1648719.6250
# Epoch 63/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5602WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1648568.5000
# Epoch 64/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4799WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1648418.0000
# Epoch 65/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4149WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1648268.1250
# Epoch 66/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3639WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1648118.5000
# Epoch 67/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3255WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1647969.5000
# Epoch 68/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2982WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1647820.8750
# Epoch 69/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2810WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1647673.0000
# Epoch 70/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2726WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 16ms/step - loss: 1647525.0000
# Epoch 71/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2719WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 15ms/step - loss: 1647378.0000
# Epoch 72/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2780WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1647230.8750
# Epoch 73/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2902WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1647084.3750
# Epoch 74/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3075WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1646938.2500
# Epoch 75/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3296WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1646792.3750
# Epoch 76/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3558WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1646646.8750
# Epoch 77/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3859WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1646501.6250
# Epoch 78/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4196WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1646356.7500
# Epoch 79/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4567WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1646212.1250
# Epoch 80/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4970WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1646067.8750
# Epoch 81/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5405WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1645923.8750
# Epoch 82/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5871WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1645779.8750
# Epoch 83/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.6369WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1645636.6250
# Epoch 84/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.6897WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1645493.3750
# Epoch 85/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.7456WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1645350.3750
# Epoch 86/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.8046WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1645207.5000
# Epoch 87/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.8666WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1645065.1250
# Epoch 88/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.9317WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1644922.6250
# Epoch 89/204
# 1/6 [====>.........................] - ETA: 0s - loss: 0.9997WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1644780.5000
# Epoch 90/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.0707WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1644638.7500
# Epoch 91/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.1448WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1644496.8750
# Epoch 92/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2218WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 15ms/step - loss: 1644355.3750
# Epoch 93/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3019WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 15ms/step - loss: 1644214.1250
# Epoch 94/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3850WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1644073.1250
# Epoch 95/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4712WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1643931.8750
# Epoch 96/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5604WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1643791.2500
# Epoch 97/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6526WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 15ms/step - loss: 1643650.6250
# Epoch 98/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7480WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1643510.1250
# Epoch 99/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8464WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1643370.1250
# Epoch 100/204
# 1/6 [====>.........................] - ETA: 0s - loss: 1.9479WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1643229.7500
# Epoch 101/204
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0525WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1643089.8750
# Epoch 102/204
# 1/6 [====>.........................] - ETA: 0s - loss: 2.1602WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 16ms/step - loss: 1642950.0000
# Epoch 103/204
# 1/6 [====>.........................] - ETA: 0s - loss: 2.2709WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1642810.2500
# Epoch 104/204
# 1/6 [====>.........................] - ETA: 0s - loss: 2.3846WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1642671.0000
# Epoch 105/204
# 1/6 [====>.........................] - ETA: 0s - loss: 2.5014WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1642531.3750
# Epoch 106/204
# 1/6 [====>.........................] - ETA: 0s - loss: 2.6210WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1642392.3750
# Epoch 107/204
# 1/6 [====>.........................] - ETA: 0s - loss: 2.7435WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1642253.2500
# Epoch 108/204
# 1/6 [====>.........................] - ETA: 0s - loss: 2.8687WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1642114.2500
# Epoch 109/204
# 1/6 [====>.........................] - ETA: 0s - loss: 2.9966WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1641975.5000
# Epoch 110/204
# 1/6 [====>.........................] - ETA: 0s - loss: 3.1271WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1641836.6250
# Epoch 111/204
# 1/6 [====>.........................] - ETA: 0s - loss: 3.2600WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1641698.2500
# Epoch 112/204
# 1/6 [====>.........................] - ETA: 0s - loss: 3.3952WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1641559.7500
# Epoch 113/204
# 1/6 [====>.........................] - ETA: 0s - loss: 3.5325WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1641421.3750
# Epoch 114/204
# 1/6 [====>.........................] - ETA: 0s - loss: 3.6717WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 17ms/step - loss: 1641283.1250
# Epoch 115/204
# 1/6 [====>.........................] - ETA: 0s - loss: 3.8126WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1641145.0000
# Epoch 116/204
# 1/6 [====>.........................] - ETA: 0s - loss: 3.9550WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1641007.1250
# Epoch 117/204
# 1/6 [====>.........................] - ETA: 0s - loss: 4.0987WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1640869.2500
# Epoch 118/204
# 1/6 [====>.........................] - ETA: 0s - loss: 4.2434WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 15ms/step - loss: 1640731.5000
# Epoch 119/204
# 1/6 [====>.........................] - ETA: 0s - loss: 4.3890WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1640593.8750
# Epoch 120/204
# 1/6 [====>.........................] - ETA: 0s - loss: 4.5350WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 16ms/step - loss: 1640456.5000
# Epoch 121/204
# 1/6 [====>.........................] - ETA: 0s - loss: 4.6812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1640319.1250
# Epoch 122/204
# 1/6 [====>.........................] - ETA: 0s - loss: 4.8275WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1640181.8750
# Epoch 123/204
# 1/6 [====>.........................] - ETA: 0s - loss: 4.9735WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1640044.7500
# Epoch 124/204
# 1/6 [====>.........................] - ETA: 0s - loss: 5.1189WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 16ms/step - loss: 1639907.7500
# Epoch 125/204
# 1/6 [====>.........................] - ETA: 0s - loss: 5.2635WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1639770.7500
# Epoch 126/204
# 1/6 [====>.........................] - ETA: 0s - loss: 5.4070WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1639634.2500
# Epoch 127/204
# 1/6 [====>.........................] - ETA: 0s - loss: 5.5492WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1639497.3750
# Epoch 128/204
# 1/6 [====>.........................] - ETA: 0s - loss: 5.6900WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 16ms/step - loss: 1639360.8750
# Epoch 129/204
# 1/6 [====>.........................] - ETA: 0s - loss: 5.8289WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1639224.5000
# Epoch 130/204
# 1/6 [====>.........................] - ETA: 0s - loss: 5.9660WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1639088.2500
# Epoch 131/204
# 1/6 [====>.........................] - ETA: 0s - loss: 6.1010WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1638952.0000
# Epoch 132/204
# 1/6 [====>.........................] - ETA: 0s - loss: 6.2337WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1638815.8750
# Epoch 133/204
# 1/6 [====>.........................] - ETA: 0s - loss: 6.3639WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1638680.0000
# Epoch 134/204
# 1/6 [====>.........................] - ETA: 0s - loss: 6.4917WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1638544.0000
# Epoch 135/204
# 1/6 [====>.........................] - ETA: 0s - loss: 6.6169WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1638408.2500
# Epoch 136/204
# 1/6 [====>.........................] - ETA: 0s - loss: 6.7393WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 15ms/step - loss: 1638272.5000
# Epoch 137/204
# 1/6 [====>.........................] - ETA: 0s - loss: 6.8589WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1638137.0000
# Epoch 138/204
# 1/6 [====>.........................] - ETA: 0s - loss: 6.9757WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1638001.6250
# Epoch 139/204
# 1/6 [====>.........................] - ETA: 0s - loss: 7.0897WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# ...
# 6/6 [==============================] - 0s 13ms/step - loss: 1635396.7500
# Epoch 159/204
# 1/6 [====>.........................] - ETA: 0s - loss: 4.9919WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1635240.8750
# Epoch 160/204
# 1/6 [====>.........................] - ETA: 0s - loss: 5.8449WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1635072.0000
# Epoch 161/204
# 1/6 [====>.........................] - ETA: 0s - loss: 6.8331WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1634918.5000
# Epoch 162/204
# 1/6 [====>.........................] - ETA: 0s - loss: 7.4165WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1634794.1250
# Epoch 163/204
# 1/6 [====>.........................] - ETA: 0s - loss: 7.1208WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1634650.5000
# Epoch 164/204
# 1/6 [====>.........................] - ETA: 0s - loss: 6.7316WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1634521.0000
# Epoch 165/204
# 1/6 [====>.........................] - ETA: 0s - loss: 6.8848WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 16ms/step - loss: 1634385.1250
# Epoch 166/204
# 1/6 [====>.........................] - ETA: 0s - loss: 7.2747WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1634251.5000
# Epoch 167/204
# 1/6 [====>.........................] - ETA: 0s - loss: 7.4664WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1634117.3750
# Epoch 168/204
# 1/6 [====>.........................] - ETA: 0s - loss: 7.4659WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1633984.0000
# Epoch 169/204
# 1/6 [====>.........................] - ETA: 0s - loss: 7.5478WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1633850.7500
# Epoch 170/204
# 1/6 [====>.........................] - ETA: 0s - loss: 7.7482WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1633717.3750
# Epoch 171/204
# 1/6 [====>.........................] - ETA: 0s - loss: 7.9103WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1633584.0000
# Epoch 172/204
# 1/6 [====>.........................] - ETA: 0s - loss: 8.0063WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1633451.1250
# Epoch 173/204
# 1/6 [====>.........................] - ETA: 0s - loss: 8.1257WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1633318.0000
# Epoch 174/204
# 1/6 [====>.........................] - ETA: 0s - loss: 8.2715WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 16ms/step - loss: 1633185.1250
# Epoch 175/204
# 1/6 [====>.........................] - ETA: 0s - loss: 8.3903WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1633052.1250
# Epoch 176/204
# 1/6 [====>.........................] - ETA: 0s - loss: 8.4971WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1632919.2500
# Epoch 177/204
# 1/6 [====>.........................] - ETA: 0s - loss: 8.6152WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1632786.6250
# Epoch 178/204
# 1/6 [====>.........................] - ETA: 0s - loss: 8.7241WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1632654.0000
# Epoch 179/204
# 1/6 [====>.........................] - ETA: 0s - loss: 8.8232WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1632521.3750
# Epoch 180/204
# 1/6 [====>.........................] - ETA: 0s - loss: 8.9238WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1632388.8750
# Epoch 181/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.0177WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1632256.5000
# Epoch 182/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.1059WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1632124.1250
# Epoch 183/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.1919WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1631991.8750
# Epoch 184/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.2719WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1631859.5000
# Epoch 185/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.3483WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1631727.1250
# Epoch 186/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.4205WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1631595.1250
# Epoch 187/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.4884WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1631463.1250
# Epoch 188/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.5526WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1631331.1250
# Epoch 189/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.6126WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1631199.1250
# Epoch 190/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.6691WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1631067.1250
# Epoch 191/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.7218WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1630935.2500
# Epoch 192/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.7711WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 21ms/step - loss: 1630803.3750
# Epoch 193/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.8166WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1630671.7500
# Epoch 194/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.8594WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1630540.1250
# Epoch 195/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.8977WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1630408.3750
# Epoch 196/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.9354WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1630276.7500
# Epoch 197/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.9648WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 16ms/step - loss: 1630145.1250
# Epoch 198/204
# 1/6 [====>.........................] - ETA: 0s - loss: 10.0024WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 14ms/step - loss: 1630013.7500
# Epoch 199/204
# 1/6 [====>.........................] - ETA: 0s - loss: 10.0105WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 12ms/step - loss: 1629882.3750
# Epoch 200/204
# 1/6 [====>.........................] - ETA: 0s - loss: 10.0757WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 15ms/step - loss: 1629751.2500
# Epoch 201/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.9683WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1629622.1250
# Epoch 202/204
# 1/6 [====>.........................] - ETA: 0s - loss: 10.2729WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1629511.2500
# Epoch 203/204
# 1/6 [====>.........................] - ETA: 0s - loss: 9.2385WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 16ms/step - loss: 1629417.1250
# Epoch 204/204
# 1/6 [====>.........................] - ETA: 0s - loss: 8.3744WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/6 [==============================] - 0s 13ms/step - loss: 1629279.1250

# %%
history.history.keys()
# Out:
# dict_keys(['loss'])

# %%
def visualize_loss(history, title):
    loss = history.history["loss"]
    #val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    #plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()


visualize_loss(history, "Training and Validation Loss")

# %%
# convert the training history to a dataframe
history_df = pd.DataFrame(history.history)
# use Pandas native plot method
history_df['loss'].plot()
history_df['val_loss'].plot()
history_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Eduar\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Eduar\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Eduar\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'val_loss'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Eduar\PycharmProjects\CERI_HackX\Covid_Cases_Predictor-main\Covid_Predictor_Main.ipynb Cell 19 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Eduar/PycharmProjects/CERI_HackX/Covid_Cases_Predictor-main/Covid_Predictor_Main.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> # use Pandas native plot method
#       <a href='vscode-notebook-cell:/c%3A/Users/Eduar/PycharmProjects/CERI_HackX/Covid_Cases_Predictor-main/Covid_Predictor_Main.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> history_df['loss'].plot()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Eduar/PycharmProjects/CERI_HackX/Covid_Cases_Predictor-main/Covid_Predictor_Main.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a> history_df['val_loss'].plot()
#       <a href='vscode-notebook-cell:/c%3A/Users/Eduar/PycharmProjects/CERI_HackX/Covid_Cases_Predictor-main/Covid_Predictor_Main.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a> history_df
#
# File c:\Users\Eduar\Anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\Eduar\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'val_loss'

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future + 5) * 2])
    plt.xlabel("Time-Step")
    plt.show()
    return


for x, y in dataset_val.take(5):
    show_plot(
        [x[0][:, 1].numpy(), y[0].numpy(), model.predict(x)[0]],
        12,
        "Single Step Prediction",
    )

# %%
import matplotlib.pyplot as plt
t_train=[0]*X_train.shape[0]
for i in range(X_train.shape[0]):
    t_train[i]=X_train.numpy()[i][0]
t_test=[0]*X_test.shape[0]
for i in range(X_test.shape[0]):
    t_test[i]=X_test.numpy()[i][0]
y_test_predict=model.predict(X_test)
y_train_predict=model.predict(X_train)
plt.plot(t_train,y_train)
plt.plot(t_test,y_test)
plt.plot(t_test,y_test_predict)
plt.plot(t_train,y_train_predict)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Eduar\PycharmProjects\CERI_HackX\Covid_Cases_Predictor-main\Covid_Predictor_Main.ipynb Cell 19 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Eduar/PycharmProjects/CERI_HackX/Covid_Cases_Predictor-main/Covid_Predictor_Main.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> t_train=[0]*X_train.shape[0]
#       <a href='vscode-notebook-cell:/c%3A/Users/Eduar/PycharmProjects/CERI_HackX/Covid_Cases_Predictor-main/Covid_Predictor_Main.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> for i in range(X_train.shape[0]):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Eduar/PycharmProjects/CERI_HackX/Covid_Cases_Predictor-main/Covid_Predictor_Main.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a>     t_train[i]=X_train.numpy()[i][0]
#       <a href='vscode-notebook-cell:/c%3A/Users/Eduar/PycharmProjects/CERI_HackX/Covid_Cases_Predictor-main/Covid_Predictor_Main.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> t_test=[0]*X_test.shape[0]
#       <a href='vscode-notebook-cell:/c%3A/Users/Eduar/PycharmProjects/CERI_HackX/Covid_Cases_Predictor-main/Covid_Predictor_Main.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a> for i in range(X_test.shape[0]):
#
# File c:\Users\Eduar\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'numpy'
